# %% [markdown]
# ---
# title: 'Dreaming with sparse autoencoder features'
# date: 10/08/2024
# author:
#   - name:
#       given: T. Ben
#       family: Thompson
#     email: t.ben.thompson@gmail.com
# bibliography: biblio.bib
# format:
#   html: default
#   ipynb: default
# description: Better token optimization to maximize SAE features.
# ---

# %% [markdown]
# I get a lot of questions about dreaming/feature visualization applied to sparse autoencoders (SAEs) [^bloom]. When we were writing [Fluent dreaming for language model](https://arxiv.org/abs/2402.01702) and [the companion post for that paper](https://confirmlabs.org/posts/dreamy.html), we thought that a natural application of feature visualization would be sparse autoencoder features because the features should be fairly monosemantic. But there weren't any open source SAE features yet and we didn't want to put the effort in to train our own SAE features.
#
# Since then, several open source SAEs have been released [@bloom2024gpt2residualsaes; @lieberum2024gemmascopeopensparse]. This post will demonstrate dreaming applied to SAE features. Technically, this is an extremely simple modification because an SAE encoder or decoder feature is just a direction in activation space.
#
# In addition, since writing the dreaming paper, [we have worked on state of the art token optimization methods](https://confirmlabs.org/posts/flrt.html) [@thompson2024flrtfluentstudentteacherredteaming]. I use these new token optimization methods here.
#
# The rest of this post is a self-contained notebook for feature visualization of SAE features [^disclaimer].
#
# [^bloom]: As a specific motivation for this post, Joseph Bloom recently got in touch to ask about applying feature visualization techniques to SAEs. I wrote this with him in mind.
#
# [^disclaimer]: As a disclaimer, the code below has not been heavily used and was written just for this post. I expect inefficiences and possibly some bugs.

# %% [markdown]
# ## Setup

# %% [markdown]
# In this first section, we setup our environment and define a few useful functions:
#
# - `add_fwd_hooks` is a context manager for adding forward hooks to a model so that we can store and later access intermediate activations.
# - `load_sae` loads a Gemma Scope SAE for the specified layer.
# - `calc_xe` calculates a batched cross-entropy loss for the purpose of fluency scoring.

# %%
#| output: false
import random
import time

import numpy as np
import sae_lens
import torch
import matplotlib.pyplot as plt
from transformers import AutoModelForCausalLM, AutoTokenizer

torch.set_default_device("cuda")
# While we will use gradients later, we don't need them for most operations and
# will explicitly enable gradients when needed.
torch.set_grad_enabled(False)

# %%
import contextlib
from typing import Callable, List, Tuple


@contextlib.contextmanager
def add_fwd_hooks(module_hooks: List[Tuple[torch.nn.Module, Callable]]):
    """
    Context manager for temporarily adding forward hooks to a model.

    Parameters
    ----------
    module_hooks
        A list of pairs: (module, fnc) The function will be registered as a
            forward hook on the module
    """
    try:
        handles = []
        for mod, hk in module_hooks:
            handles.append(mod.register_forward_hook(hk))
        yield
    finally:
        for h in handles:
            h.remove()


sae_cache = {}


def load_sae(layer):
    sae_id = f"layer_{layer}/width_16k/canonical"
    if sae_id not in sae_cache:
        sae, _, _ = sae_lens.SAE.from_pretrained(
            release="gemma-scope-2b-pt-res-canonical",
            sae_id=sae_id,
            device="cuda",
        )
        sae_cache[sae_id] = sae
    else:
        sae = sae_cache[sae_id]
    return sae


def calc_xe(logits, input_ids):
    return (
        torch.nn.functional.cross_entropy(
            logits[:, :-1].reshape(-1, logits.shape[-1]),
            input_ids[:, 1:].reshape(-1),
            reduction="none",
        )
        .reshape((logits.shape[0], -1))
        .mean(dim=-1)
    )

# %% [markdown]
# ## Dreaming
#
# This section defines a `dream` function for optimizing token sequences to maximize a provided feature.
#
# Broadly, the algorithm works as follows:
#
# 1. Mutate the current token sequence into `explore` new sequences.
# 2. Evaluate the feature activation and fluency of the new sequences.
# 3. Retain the best sequences.
# 4. Repeat.
#
# The most important parameter is `get_feature_and_logits`. This function should accept a batch of sequences and return the target feature as well as the full logits tensor from calling the model. In the next section, we will provide a few examples of how to use this function with SAEs.
#
# Follow along with the code comments for more detail.
#
# :::{.column-body-outset}

# %%
def dream(
    model: AutoModelForCausalLM,
    tokenizer: AutoTokenizer,
    # This function accepts a batch of sequences and returns the target feature
    # as well as the full logits tensor from calling the model.
    get_feature_and_logits: Callable,
    init_prompt: str = "help! are you a purple bobcat?",
    verbose: bool = True,  # Print status updates.
    iters: int = 500,  # Number of iterations
    seed: int = 0,
    #
    # There are two approaches to fluency control:
    # 1. `xe_max` sets an absolute limit on the cross-entropy loss.
    # 2. `xe_regularization` adds a cross-entropy fluency penalty to the loss
    #    function.
    xe_max: float = None,
    xe_regularization: float = 0.0,
    buffer_size: int = 4,  # Number of prompts to keep in the buffer
    #
    # Parameters for choosing the type of mutation operation at each iteration.
    min_tokens: int = 8,  # Minimum allowed number of tokens
    max_tokens: int = 16,  # Maximum allowed number of tokens
    p_gcg_swap: float = 0.25,  # prob of an iteration being a gcg swap
    p_sample_insert: float = 0.25,  # prob of an iteration being a sampled insert
    p_sample_swap: float = 0.25,  # prob of an iteration being a sampled swap
    p_delete: float = 0.25,  # prob of an iteration being a delete
    #
    # Mutation parameters:
    # - `sample_k2`: For sampled mutations, we sample without
    #   replacement`sample_k2` candidate tokens per token position.
    # - `gcg_topk`: For GCG, we select swap tokens from the top `gcg_topk`
    #   tokens according to the loss gradient.
    # after sampling, we have a (n_tokens, k2 or gcg_topk) matrix of candidate tokens
    # then, for each child candidate, we sample a random entry from this matrix
    # and perform the corresponding mutation.
    sample_k2: int = 16,
    gcg_topk: int = 512,
    explore: int = 128,  # Number of child candidates per parent
):
    # Set random seeds.
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    # We track the best prompts in a buffer. At each step, we remove the best
    # prompt and mutate it to produce new candidates. Then, we merge those
    # candidates back into the buffer.
    buffer_prompts = [init_prompt] * buffer_size
    buffer_losses = torch.tensor([float("inf")] * buffer_size)

    # Track the history of the best prompts in run.
    history = []

    for IT in range(iters):
        start = time.time()

        # At each step, we choose randomly between the four types of
        # operations. See below for precise descriptions of these operations.
        operation_idx = torch.multinomial(
            torch.tensor([p_gcg_swap, p_sample_insert, p_sample_swap, p_delete]), 1
        ).item()
        operation = ["gcg_swap", "sample_insert", "sample_swap", "delete"][
            operation_idx
        ]

        input_ids = tokenizer.encode(
            buffer_prompts[0], return_tensors="pt", add_special_tokens=False
        )

        # If the prompt is too short or too long, we force a different
        # operation.
        n_tokens = input_ids.shape[1]
        if n_tokens < min_tokens:
            operation = "sample_insert"
        elif n_tokens > max_tokens:
            operation = "delete"

        if operation == "gcg_swap":
            #########################
            # GCG SWAP
            #########################
            # A GCG swap proceeds as in Zou et al 2023:
            # - we backpropagate the loss to get the gradient of the loss with
            #   respect to each token in each token position
            # - we select the top K tokens in each position according to the loss gradient
            # - we sample uniformly at random between the token positions
            # - we sample uniformly among the top K tokens in each position
            with torch.enable_grad():
                embed = model.model.embed_tokens
                one_hot = torch.nn.functional.one_hot(
                    input_ids.clone(), num_classes=embed.num_embeddings
                ).to(embed.weight.dtype)
                one_hot.requires_grad = True
                embeds = torch.matmul(one_hot, embed.weight)
                feature, logits = get_feature_and_logits(inputs_embeds=embeds)
                (-feature).backward()

                topk_grad = (-one_hot.grad).topk(k=gcg_topk, dim=-1)
                token_pos = torch.randint(0, input_ids.shape[1], (explore,))
                topk_idx = torch.randint(0, gcg_topk, (explore,))
                candidate_ids = input_ids[0, None, :].repeat(explore, 1)
                candidate_ids[torch.arange(explore), token_pos] = topk_grad.indices[
                    0, token_pos, topk_idx
                ]
        elif operation == "sample_insert":
            ##################
            # SAMPLE INSERT
            ##################
            # A sample insert proceeds similarly to the mutation operation from
            # the BEAST paper (Sadasivan et al 2024) but incorporates features from GCG:
            # - we produce the next token probability distribution for each token position.
            # - we sample K tokens without replacement from the probability
            #   distribution for each token position.
            # - we select uniformly at random from the token positions.
            # - then we sample uniformly at random from those K tokens.
            logits = model(input_ids=input_ids).logits
            probs = torch.softmax(logits[0], dim=-1)
            candidate_ids = torch.empty((explore, n_tokens + 1), dtype=torch.long)
            insert_position = torch.randint(1, n_tokens + 1, (explore,))
            insert_probs = probs[insert_position - 1]
            sampled_ids = torch.multinomial(insert_probs, num_samples=sample_k2)
            sample_idx = torch.randint(0, sample_k2, (explore,))
            insert_ids = sampled_ids[torch.arange(explore), sample_idx]
            for j in range(explore):
                candidate_ids[j, : insert_position[j]] = input_ids[
                    0, : insert_position[j]
                ]
                candidate_ids[j, insert_position[j]] = insert_ids[j]
                candidate_ids[j, insert_position[j] + 1 :] = input_ids[
                    0, insert_position[j] :
                ]
        elif operation == "sample_swap":
            #################
            # SAMPLE SWAP
            #################
            # A sample swap proceeds similarly to the sample insert operation
            # except that we swap a token instead of inserting a new token.
            logits = model(input_ids).logits
            probs = torch.softmax(logits[0], dim=-1)
            candidate_ids = input_ids[0, None, :].repeat(explore, 1)
            swap_position = torch.randint(1, n_tokens, (explore,))
            swap_probs = probs[swap_position]
            sampled_ids = torch.multinomial(swap_probs, num_samples=sample_k2)
            sample_idx = torch.randint(0, sample_k2, (explore,))
            swap_ids = sampled_ids[torch.arange(explore), sample_idx]
            candidate_ids[torch.arange(explore), swap_position] = swap_ids
        elif operation == "delete":
            #################
            # DELETE
            #################
            # A delete operation removes a token from the prompt.
            # The set of candidates is the set of all possible deletions.
            if explore > n_tokens:
                n_candidates = n_tokens
                delete_indices = torch.arange(n_tokens)
            else:
                n_candidates = explore
                delete_indices = torch.randperm(n_tokens)[:n_candidates]

            candidate_ids = torch.empty((n_candidates, n_tokens - 1), dtype=torch.long)
            for i in range(n_candidates):
                candidate_ids[i, : delete_indices[i]] = input_ids[
                    0, : delete_indices[i]
                ]
                candidate_ids[i, delete_indices[i] :] = input_ids[
                    0, delete_indices[i] + 1 :
                ]

        # To avoid issues with special tokens, we decode and re-encode.
        candidates = tokenizer.batch_decode(candidate_ids, skip_special_tokens=True)
        candidates_tokenized = tokenizer(candidates, padding=True, return_tensors="pt")

        ################
        # Calculate loss
        ################
        feature, logits = get_feature_and_logits(**candidates_tokenized)
        xe = calc_xe(logits, candidates_tokenized["input_ids"])
        # We maximize activation, so negate activation.
        candidate_losses = -feature + xe_regularization * xe
        if xe_max is not None:
            candidate_losses = torch.where(xe > xe_max, float("inf"), candidate_losses)
        best_idx = torch.argmin(candidate_losses)

        #########################
        # Update the top-N buffer
        #########################
        # Update the top-N buffer. We remove the first element because we used it
        # up this iteration. Then, we select the top-N best sequences between the
        # existing buffer entries and the new candidates.
        combined_prompts = buffer_prompts[1:] + candidates
        combined_losses = torch.cat([buffer_losses[1:], candidate_losses])
        keep_idxs = torch.argsort(combined_losses)[:buffer_size]
        buffer_prompts = [combined_prompts[i] for i in keep_idxs]
        buffer_losses = combined_losses[keep_idxs]

        # Report on the step and record the history.
        runtime = time.time() - start
        if verbose:
            print("\n\n")
            print(f"Iteration {IT} | Operation: {operation}")
            print(
                f"Loss={candidate_losses[best_idx].item():.2f}"
                f" | Activation={feature[best_idx].item():.2f}"
                f" | XE={xe[best_idx].item():.2f}"
            )
            print(f"Runtime={runtime:.2f}s")
            print(f"Best candidate: {buffer_prompts[0]}")
        history.append(
            dict(
                operation=operation,
                runtime=runtime,
                activation=feature[best_idx].item(),
                xe=xe[best_idx].item(),
                seq=buffer_prompts[0],
            )
        )
    return history

# %% [markdown]
# :::

# %% [markdown]
# ## Dreaming encoder directions

# %% [markdown]
# In this section, we will run feature visualization on a particular SAE encoder direction.
#
# First, we'll load up Gemma 2 2B.

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "google/gemma-2-2b", clean_up_tokenization_spaces=False
)
gemma2 = AutoModelForCausalLM.from_pretrained(
    "google/gemma-2-2b",
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    device_map="cuda",
    attn_implementation="flash_attention_2",
)
gemma2 = gemma2.requires_grad_(False)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Then we'll define a function for getting the activation of the particular SAE latent. Importantly, we'll grab the latent before it is passed through the ReLU activation function or any other thresholding operation. That will make optimization easier. The generated `f` function will be passed as the `get_feature_and_logits` argument to the `dream` function.

# %%
def gemma_sae_encoder(gemma2, layer, feature_idx):
    def f(input_ids=None, inputs_embeds=None, attention_mask=None):
        out = {}

        def get_res(module, input, output):
            out["res"] = input[0]

        model_hooks = [
            (gemma2.model.layers[layer], get_res),
        ]
        with add_fwd_hooks(model_hooks):
            if inputs_embeds is not None:
                logits = gemma2(
                    inputs_embeds=inputs_embeds, attention_mask=attention_mask
                ).logits
            else:
                logits = gemma2(
                    input_ids=input_ids, attention_mask=attention_mask
                ).logits

        def get_sae_pre(module, input, output):
            out["sae_pre"] = input[0]

        sae = load_sae(layer)
        sae_hooks = [(sae.hook_sae_acts_pre, get_sae_pre)]
        with add_fwd_hooks(sae_hooks):
            sae.encode(out["res"])

        return out["sae_pre"][:, -1, feature_idx], logits

    return f

# %% [markdown]
# Let's look at layer 12, feature 0. Looking at neuronpedia, this feature seems to respond strongly to variants of the word "label". We run a bunch of examples through the SAE and see how they score:

# %%
layer = 12
feature_idx = 0
for text in [
    "label",
    "labl",
    "LBL",
    "lbl",
    "LABEL",
    "labal",
    "L",
    "B",
    "bel",
    "la",
    "abel",
]:
    inputs = tokenizer([text], padding=True, return_tensors="pt")
    feature, logits = gemma_sae_encoder(gemma2, layer, feature_idx)(
        input_ids=inputs["input_ids"]
    )
    print(f"Text = {text!r:8} | Activation = {feature.item():.2f}")
# Out:
# Text = 'label'  | Activation = 55.03
# Text = 'labl'   | Activation = 16.46
# Text = 'LBL'    | Activation = 15.48
# Text = 'lbl'    | Activation = 26.45
# Text = 'LABEL'  | Activation = 49.56
# Text = 'labal'  | Activation = 14.07
# Text = 'L'      | Activation = -3.95
# Text = 'B'      | Activation = -6.75
# Text = 'bel'    | Activation = 3.60
# Text = 'la'     | Activation = -0.55
# Text = 'abel'   | Activation = 15.67

# %% [markdown]
# And now let's run our feature visualization on this encoder direction. After about 20 iterations, the optimization finds the "labl" phrase and then after about 100 iterations, it finds "label".
#
# The output of the `dream` function itself is hidden below. Download the original notebook to see it.

# %%
# | output: false

encoder_history = dream(
    gemma2,
    tokenizer,
    get_feature_and_logits=gemma_sae_encoder(gemma2, layer, feature_idx),
    iters=150,
    init_prompt="help",
    xe_max=10.0,
)
# Out:
# Iteration 0 | Operation: sample_insert
# Loss=13.11 | Activation=-13.11 | XE=8.67
# Runtime=0.20s
# Best candidate: helpyou
#
#
#
# Iteration 1 | Operation: sample_insert
# Loss=2.71 | Activation=-2.71 | XE=9.80
# Runtime=0.18s
# Best candidate: helpyoubl
#
#
#
# Iteration 2 | Operation: sample_insert
# Loss=5.67 | Activation=-5.67 | XE=9.44
# Runtime=0.18s
# Best candidate: helpyoupla
#
#
#
# Iteration 3 | Operation: sample_insert
# Loss=1.00 | Activation=-1.00 | XE=8.39
# Runtime=0.18s
# Best candidate: helpyouphypla
#
#
#
# Iteration 4 | Operation: sample_insert
# Loss=-0.06 | Activation=0.06 | XE=7.93
# Runtime=0.19s
# Best candidate: helpyouphypassla
#
#
#
# Iteration 5 | Operation: sample_insert
# Loss=-1.52 | Activation=1.52 | XE=9.83
# Runtime=0.22s
# Best candidate: helpyouphypypassla
#
#
#
# Iteration 6 | Operation: delete
# Loss=-1.21 | Activation=1.21 | XE=9.29
# Runtime=0.07s
# Best candidate: helpyouphypypassla
#
#
#
# Iteration 7 | Operation: gcg_swap
# Loss=-0.83 | Activation=0.83 | XE=9.32
# Runtime=0.24s
# Best candidate: helpyouphypypassla
#
#
#
# Iteration 8 | Operation: delete
# Loss=-1.21 | Activation=1.21 | XE=9.29
# Runtime=0.07s
# Best candidate: helpyouphypypassla
#
#
#
# Iteration 9 | Operation: sample_insert
# Loss=-11.11 | Activation=11.11 | XE=8.28
# Runtime=0.22s
# Best candidate: helpyouphypypasslabl
#
#
#
# Iteration 10 | Operation: sample_insert
# Loss=-17.18 | Activation=17.18 | XE=7.73
# Runtime=0.22s
# Best candidate: helpyouphypypass-labl
#
#
#
# Iteration 11 | Operation: sample_swap
# Loss=-19.61 | Activation=19.61 | XE=9.41
# Runtime=0.21s
# Best candidate: helpyouphyp
# ass-labl
#
#
#
# Iteration 12 | Operation: delete
# Loss=-20.32 | Activation=20.32 | XE=9.29
# Runtime=0.08s
# Best candidate: pyouphyp
# ass-labl
#
#
#
# Iteration 13 | Operation: sample_swap
# Loss=-19.53 | Activation=19.53 | XE=8.51
# Runtime=0.20s
# Best candidate: helpyphyp
# ass-labl
#
#
#
# Iteration 14 | Operation: sample_insert
# Loss=-20.84 | Activation=20.84 | XE=9.00
# Runtime=0.23s
# Best candidate: helpyphyp
# ass ass-labl
#
#
#
# Iteration 15 | Operation: sample_swap
# Loss=-21.65 | Activation=21.65 | XE=9.82
# Runtime=0.20s
# Best candidate: helpyphyp
# ass add-labl
#
#
#
# Iteration 16 | Operation: delete
# Loss=-21.49 | Activation=21.49 | XE=8.74
# Runtime=0.07s
# Best candidate: helpyphypass add-labl
#
#
#
# Iteration 17 | Operation: sample_insert
# Loss=-22.52 | Activation=22.52 | XE=9.29
# Runtime=0.24s
# Best candidate: helpy
# phypass add-labl
#
#
#
# Iteration 18 | Operation: sample_swap
# Loss=-23.06 | Activation=23.06 | XE=8.32
# Runtime=0.20s
# Best candidate: helpy
# +ypass add-labl
#
#
#
# Iteration 19 | Operation: sample_insert
# Loss=-23.82 | Activation=23.82 | XE=9.23
# Runtime=0.25s
# Best candidate: helpy
# +ypass add-autolabl
#
#
#
# Iteration 20 | Operation: gcg_swap
# Loss=-24.12 | Activation=24.12 | XE=9.82
# Runtime=0.28s
# Best candidate: helpy
# +yppeace add-autolabl
#
#
#
# Iteration 21 | Operation: delete
# Loss=-24.90 | Activation=24.90 | XE=9.03
# Runtime=0.07s
# Best candidate: py
# +yppeace add-autolabl
#
#
#
# Iteration 22 | Operation: delete
# Loss=-24.94 | Activation=24.94 | XE=8.39
# Runtime=0.07s
# Best candidate: py
# +ypp add-autolabl
#
#
#
# Iteration 23 | Operation: delete
# Loss=-25.04 | Activation=25.04 | XE=8.75
# Runtime=0.07s
# Best candidate: py
# ypp add-autolabl
#
#
#
# Iteration 24 | Operation: sample_swap
# Loss=-25.05 | Activation=25.05 | XE=9.92
# Runtime=0.20s
# Best candidate: py
# ypp add-autolabl
#
#
#
# Iteration 25 | Operation: sample_swap
# Loss=-25.05 | Activation=25.05 | XE=9.92
# Runtime=0.20s
# Best candidate: py
# ypp add-autolabl
#
#
#
# Iteration 26 | Operation: sample_insert
# Loss=-25.47 | Activation=25.47 | XE=9.00
# Runtime=0.25s
# Best candidate: pyy
# ypp add-autolabl
#
#
#
# Iteration 27 | Operation: delete
# Loss=-25.04 | Activation=25.04 | XE=8.75
# Runtime=0.07s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 28 | Operation: sample_swap
# Loss=-25.53 | Activation=25.53 | XE=9.50
# Runtime=0.21s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 29 | Operation: delete
# Loss=-25.23 | Activation=25.23 | XE=8.17
# Runtime=0.07s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 30 | Operation: sample_swap
# Loss=-25.53 | Activation=25.53 | XE=9.50
# Runtime=0.21s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 31 | Operation: gcg_swap
# Loss=-24.11 | Activation=24.11 | XE=9.16
# Runtime=0.28s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 32 | Operation: delete
# Loss=-25.23 | Activation=25.23 | XE=8.17
# Runtime=0.07s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 33 | Operation: gcg_swap
# Loss=-24.44 | Activation=24.44 | XE=9.86
# Runtime=0.27s
# Best candidate: py
# @ypp add-autolabl
#
#
#
# Iteration 34 | Operation: gcg_swap
# Loss=-25.22 | Activation=25.22 | XE=9.52
# Runtime=0.27s
# Best candidate:
# @ypp add-autolabl
#
#
#
# Iteration 35 | Operation: gcg_swap
# Loss=-25.50 | Activation=25.50 | XE=9.52
# Runtime=0.26s
# Best candidate:
# @ypapi add-autolabl
#
#
#
# Iteration 36 | Operation: sample_swap
# Loss=-25.75 | Activation=25.75 | XE=10.00
# Runtime=0.20s
# Best candidate:
# //@ypapi add-autolabl
#
#
#
# Iteration 37 | Operation: sample_swap
# Loss=-26.30 | Activation=26.30 | XE=9.95
# Runtime=0.20s
# Best candidate:
# #@ypapi add-autolabl
#
#
#
# Iteration 38 | Operation: delete
# Loss=-26.47 | Activation=26.47 | XE=9.34
# Runtime=0.07s
# Best candidate:
# #@papi add-autolabl
#
#
#
# Iteration 39 | Operation: delete
# Loss=-24.51 | Activation=24.51 | XE=9.12
# Runtime=0.07s
# Best candidate:
# @ypapi add-autolabl
#
#
#
# Iteration 40 | Operation: delete
# Loss=-25.10 | Activation=25.10 | XE=8.14
# Runtime=0.07s
# Best candidate:
# @ypapi add-autolabl
#
#
#
# Iteration 41 | Operation: sample_swap
# Loss=-25.48 | Activation=25.48 | XE=9.70
# Runtime=0.20s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 42 | Operation: sample_swap
# Loss=-25.48 | Activation=25.48 | XE=9.70
# Runtime=0.20s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 43 | Operation: delete
# Loss=-25.10 | Activation=25.10 | XE=8.14
# Runtime=0.07s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 44 | Operation: sample_insert
# Loss=-25.53 | Activation=25.53 | XE=8.34
# Runtime=0.22s
# Best candidate:
# @<unused61>spapi add-autolabl
#
#
#
# Iteration 45 | Operation: delete
# Loss=-25.31 | Activation=25.31 | XE=9.36
# Runtime=0.07s
# Best candidate:
# @<unused61>papi add option-autolabl
#
#
#
# Iteration 46 | Operation: delete
# Loss=-25.36 | Activation=25.36 | XE=8.51
# Runtime=0.07s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 47 | Operation: sample_insert
# Loss=-25.55 | Activation=25.55 | XE=9.12
# Runtime=0.23s
# Best candidate:
# @<unused61>@@@papi add-autolabl
#
#
#
# Iteration 48 | Operation: gcg_swap
# Loss=-24.76 | Activation=24.76 | XE=9.82
# Runtime=0.27s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 49 | Operation: sample_swap
# Loss=-25.48 | Activation=25.48 | XE=9.70
# Runtime=0.20s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 50 | Operation: delete
# Loss=-25.10 | Activation=25.10 | XE=8.14
# Runtime=0.07s
# Best candidate:
# @<unused61>papi add-autolabl
#
#
#
# Iteration 51 | Operation: sample_insert
# Loss=-25.60 | Activation=25.60 | XE=8.97
# Runtime=0.22s
# Best candidate:
# @<unused61>papihp add-autolabl
#
#
#
# Iteration 52 | Operation: sample_swap
# Loss=-25.71 | Activation=25.71 | XE=9.96
# Runtime=0.21s
# Best candidate:
# @papihp add-autolabl
#
#
#
# Iteration 53 | Operation: delete
# Loss=-25.15 | Activation=25.15 | XE=8.62
# Runtime=0.07s
# Best candidate:
# @<unused61>@hp add-autolabl
#
#
#
# Iteration 54 | Operation: sample_swap
# Loss=-26.07 | Activation=26.07 | XE=9.97
# Runtime=0.21s
# Best candidate:
# @#@hp add-autolabl
#
#
#
# Iteration 55 | Operation: gcg_swap
# Loss=-24.83 | Activation=24.83 | XE=9.73
# Runtime=0.26s
# Best candidate:
# @
#
#
# @hp add-autolabl
#
#
#
# Iteration 56 | Operation: sample_swap
# Loss=-25.90 | Activation=25.90 | XE=9.34
# Runtime=0.21s
# Best candidate:
# @
#
#
# @hp add-autolabl
#
#
#
# Iteration 57 | Operation: sample_insert
# Loss=-26.37 | Activation=26.37 | XE=9.03
# Runtime=0.28s
# Best candidate:
# @
#
#
# @hpmap add-autolabl
#
#
#
# Iteration 58 | Operation: sample_swap
# Loss=-26.73 | Activation=26.73 | XE=8.73
# Runtime=0.22s
# Best candidate:
# @
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 59 | Operation: sample_insert
# Loss=-26.93 | Activation=26.93 | XE=8.98
# Runtime=0.26s
# Best candidate:
# @
#
#
# @mpwnmap add-autolabl
#
#
#
# Iteration 60 | Operation: delete
# Loss=-26.88 | Activation=26.88 | XE=7.63
# Runtime=0.07s
# Best candidate:
# @
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 61 | Operation: sample_insert
# Loss=-27.15 | Activation=27.15 | XE=8.81
# Runtime=0.26s
# Best candidate:
# @secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 62 | Operation: sample_swap
# Loss=-27.64 | Activation=27.64 | XE=9.92
# Runtime=0.26s
# Best candidate:
#  @secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 63 | Operation: gcg_swap
# Loss=-25.98 | Activation=25.98 | XE=9.80
# Runtime=0.29s
# Best candidate:
# @secret
#
#
# @mpstream add-autolabl
#
#
#
# Iteration 64 | Operation: gcg_swap
# Loss=-26.92 | Activation=26.92 | XE=9.93
# Runtime=0.29s
# Best candidate:
# @secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 65 | Operation: delete
# Loss=-27.01 | Activation=27.01 | XE=8.90
# Runtime=0.07s
# Best candidate:
# @secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 66 | Operation: sample_insert
# Loss=-27.58 | Activation=27.58 | XE=9.72
# Runtime=0.27s
# Best candidate:
# @有secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 67 | Operation: delete
# Loss=-27.23 | Activation=27.23 | XE=9.50
# Runtime=0.07s
# Best candidate:
# `@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 68 | Operation: sample_swap
# Loss=-27.69 | Activation=27.69 | XE=9.03
# Runtime=0.25s
# Best candidate:
# ` @secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 69 | Operation: delete
# Loss=-27.56 | Activation=27.56 | XE=8.95
# Runtime=0.07s
# Best candidate:
# `@secret
#
#
# @mpstream add-autolabl
#
#
#
# Iteration 70 | Operation: gcg_swap
# Loss=-27.14 | Activation=27.14 | XE=9.83
# Runtime=0.31s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 71 | Operation: sample_swap
# Loss=-27.62 | Activation=27.62 | XE=9.93
# Runtime=0.25s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 72 | Operation: gcg_swap
# Loss=-26.96 | Activation=26.96 | XE=9.87
# Runtime=0.31s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 73 | Operation: gcg_swap
# Loss=-26.47 | Activation=26.47 | XE=9.52
# Runtime=0.30s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 74 | Operation: gcg_swap
# Loss=-26.45 | Activation=26.45 | XE=9.44
# Runtime=0.30s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 75 | Operation: sample_insert
# Loss=-27.80 | Activation=27.80 | XE=9.97
# Runtime=0.29s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 76 | Operation: gcg_swap
# Loss=-26.17 | Activation=26.17 | XE=9.60
# Runtime=0.30s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 77 | Operation: delete
# Loss=-27.49 | Activation=27.49 | XE=8.88
# Runtime=0.07s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 78 | Operation: sample_insert
# Loss=-27.80 | Activation=27.80 | XE=9.97
# Runtime=0.28s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 79 | Operation: delete
# Loss=-27.49 | Activation=27.49 | XE=8.88
# Runtime=0.07s
# Best candidate:
# `{@secretsecret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 80 | Operation: delete
# Loss=-27.83 | Activation=27.83 | XE=9.10
# Runtime=0.07s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 81 | Operation: sample_swap
# Loss=-27.80 | Activation=27.80 | XE=9.97
# Runtime=0.25s
# Best candidate:
# `{@secret
#
#
# @mpmap add-autolabl
#
#
#
# Iteration 82 | Operation: sample_insert
# Loss=-28.04 | Activation=28.04 | XE=9.66
# Runtime=0.28s
# Best candidate:
# `{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 83 | Operation: sample_insert
# Loss=-28.04 | Activation=28.04 | XE=9.77
# Runtime=0.30s
# Best candidate:
# `{@`secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 84 | Operation: sample_swap
# Loss=-27.88 | Activation=27.88 | XE=9.68
# Runtime=0.26s
# Best candidate:
# `{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 85 | Operation: sample_insert
# Loss=-28.14 | Activation=28.14 | XE=9.90
# Runtime=0.29s
# Best candidate:
# `about{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 86 | Operation: gcg_swap
# Loss=-28.03 | Activation=28.03 | XE=10.00
# Runtime=0.32s
# Best candidate:
# ` '.{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 87 | Operation: sample_swap
# Loss=-28.00 | Activation=28.00 | XE=9.98
# Runtime=0.26s
# Best candidate:
# ` '.{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 88 | Operation: sample_swap
# Loss=-28.04 | Activation=28.04 | XE=9.29
# Runtime=0.27s
# Best candidate:
# ` `{@secret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 89 | Operation: sample_insert
# Loss=-28.59 | Activation=28.59 | XE=9.43
# Runtime=0.30s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 90 | Operation: sample_insert
# Loss=-28.52 | Activation=28.52 | XE=9.57
# Runtime=0.32s
# Best candidate:
# ` `{@}}secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 91 | Operation: delete
# Loss=-28.49 | Activation=28.49 | XE=8.70
# Runtime=0.08s
# Best candidate:
# ` `{@secretsettingsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 92 | Operation: delete
# Loss=-28.49 | Activation=28.49 | XE=8.70
# Runtime=0.08s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 93 | Operation: sample_swap
# Loss=-28.59 | Activation=28.59 | XE=9.43
# Runtime=0.27s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 94 | Operation: gcg_swap
# Loss=-28.55 | Activation=28.55 | XE=9.83
# Runtime=0.32s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 95 | Operation: gcg_swap
# Loss=-28.16 | Activation=28.16 | XE=9.74
# Runtime=0.35s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 96 | Operation: sample_swap
# Loss=-28.59 | Activation=28.59 | XE=9.43
# Runtime=0.27s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 97 | Operation: sample_insert
# Loss=-28.61 | Activation=28.61 | XE=9.71
# Runtime=0.31s
# Best candidate:
# ` `{@secretsettingsting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 98 | Operation: delete
# Loss=-28.49 | Activation=28.49 | XE=8.70
# Runtime=0.08s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 99 | Operation: sample_insert
# Loss=-28.63 | Activation=28.63 | XE=9.26
# Runtime=0.33s
# Best candidate:
# ` `{@secretsettingsecret
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 100 | Operation: delete
# Loss=-28.52 | Activation=28.52 | XE=9.28
# Runtime=0.08s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autolabl
#
#
#
# Iteration 101 | Operation: gcg_swap
# Loss=-47.25 | Activation=47.25 | XE=9.93
# Runtime=0.33s
# Best candidate:
# ` `{@secretsetting
#
#
# @mp1map add-autola label
#
#
#
# Iteration 102 | Operation: gcg_swap
# Loss=-47.48 | Activation=47.48 | XE=8.85
# Runtime=0.33s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp1map add-autola label
#
#
#
# Iteration 103 | Operation: delete
# Loss=-50.24 | Activation=50.24 | XE=8.94
# Runtime=0.08s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp1map-autola label
#
#
#
# Iteration 104 | Operation: delete
# Loss=-51.21 | Activation=51.21 | XE=9.22
# Runtime=0.07s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp1mapautola label
#
#
#
# Iteration 105 | Operation: gcg_swap
# Loss=-51.33 | Activation=51.33 | XE=9.69
# Runtime=0.35s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp1defutola label
#
#
#
# Iteration 106 | Operation: sample_swap
# Loss=-52.47 | Activation=52.47 | XE=9.55
# Runtime=0.27s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp1
# utola label
#
#
#
# Iteration 107 | Operation: delete
# Loss=-52.90 | Activation=52.90 | XE=9.24
# Runtime=0.08s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# @mp
# utola label
#
#
#
# Iteration 108 | Operation: sample_insert
# Loss=-53.17 | Activation=53.17 | XE=9.65
# Runtime=0.31s
# Best candidate:
# ` `{@Filmografiesetting
#
#
# `@mp
# utola label
#
#
#
# Iteration 109 | Operation: delete
# Loss=-53.37 | Activation=53.37 | XE=9.40
# Runtime=0.07s
# Best candidate:
#  `{@Filmografiesetting
#
#
# `@mp
# utola label
#
#
#
# Iteration 110 | Operation: gcg_swap
# Loss=-53.45 | Activation=53.45 | XE=9.81
# Runtime=0.32s
# Best candidate:
#  `{@vatagrafiesetting
#
#
# `@mp
# utola label
#
#
#
# Iteration 111 | Operation: sample_insert
# Loss=-54.11 | Activation=54.11 | XE=9.88
# Runtime=0.32s
# Best candidate:
#  `{@vatagrafiesetting
#
#
# `@mp
# Âutola label
#
#
#
# Iteration 112 | Operation: delete
# Loss=-54.45 | Activation=54.45 | XE=9.17
# Runtime=0.08s
# Best candidate:
#  `{@vatagrafies
#
#
# `@mp
# Âutola label
#
#
#
# Iteration 113 | Operation: sample_insert
# Loss=-54.84 | Activation=54.84 | XE=9.08
# Runtime=0.30s
# Best candidate:
#  `{@}`vatagrafies
#
#
# `@mp
# Âutola label
#
#
#
# Iteration 114 | Operation: delete
# Loss=-54.85 | Activation=54.85 | XE=9.34
# Runtime=0.08s
# Best candidate:
#  `{@}`vatagrafies`@mp
# Âutola label
#
#
#
# Iteration 115 | Operation: gcg_swap
# Loss=-54.19 | Activation=54.19 | XE=9.87
# Runtime=0.33s
# Best candidate:
#  `
# {@vatagrafies
#
#
# `@mp
# Âutola label
#
#
#
# Iteration 116 | Operation: delete
# Loss=-54.81 | Activation=54.81 | XE=9.01
# Runtime=0.08s
# Best candidate:
#  `
# {@vatagrafies`@mp
# Âutola label
#
#
#
# Iteration 117 | Operation: delete
# Loss=-54.57 | Activation=54.57 | XE=9.35
# Runtime=0.07s
# Best candidate:
#  `{@vatagrafies
#
#
# `
#
# @mp
# Âutola label
#
#
#
# Iteration 118 | Operation: delete
# Loss=-55.10 | Activation=55.10 | XE=8.85
# Runtime=0.08s
# Best candidate:
#  `{@vatagrafies`
#
# @mp
# Âutola label
#
#
#
# Iteration 119 | Operation: delete
# Loss=-54.98 | Activation=54.98 | XE=8.59
# Runtime=0.07s
# Best candidate:
#  `vatagrafies`
#
# @mp
# Âutola label
#
#
#
# Iteration 120 | Operation: delete
# Loss=-54.72 | Activation=54.72 | XE=8.38
# Runtime=0.07s
# Best candidate:
#  `{@agrafies`
#
# @mp
# Âutola label
#
#
#
# Iteration 121 | Operation: delete
# Loss=-54.44 | Activation=54.44 | XE=8.82
# Runtime=0.07s
# Best candidate:
#  `{@vatagrafies`
#
# @
# Âutola label
#
#
#
# Iteration 122 | Operation: delete
# Loss=-54.72 | Activation=54.72 | XE=8.38
# Runtime=0.07s
# Best candidate:
#  `vatagrafies`
#
# @
# Âutola label
#
#
#
# Iteration 123 | Operation: delete
# Loss=-54.74 | Activation=54.74 | XE=8.61
# Runtime=0.08s
# Best candidate:
#  `vatagraf`
#
# @
# Âutola label
#
#
#
# Iteration 124 | Operation: sample_insert
# Loss=-54.99 | Activation=54.99 | XE=9.31
# Runtime=0.28s
# Best candidate:
#  `vatagraf`
#
# @
# ÂÂutola label
#
#
#
# Iteration 125 | Operation: gcg_swap
# Loss=-54.34 | Activation=54.34 | XE=9.49
# Runtime=0.30s
# Best candidate:
#  `vatagraf`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 126 | Operation: sample_insert
# Loss=-55.12 | Activation=55.12 | XE=8.67
# Runtime=0.28s
# Best candidate:
#  `vatagueraf`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 127 | Operation: gcg_swap
# Loss=-54.78 | Activation=54.78 | XE=9.26
# Runtime=0.32s
# Best candidate:
#  `vatvatagraf`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 128 | Operation: sample_swap
# Loss=-55.02 | Activation=55.02 | XE=9.63
# Runtime=0.26s
# Best candidate:
#  `vatvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 129 | Operation: sample_insert
# Loss=-55.23 | Activation=55.23 | XE=9.87
# Runtime=0.29s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 130 | Operation: sample_swap
# Loss=-55.23 | Activation=55.23 | XE=9.87
# Runtime=0.27s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 131 | Operation: sample_swap
# Loss=-55.26 | Activation=55.26 | XE=9.71
# Runtime=0.27s
# Best candidate:
#  `vatvisvatavace`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 132 | Operation: gcg_swap
# Loss=-54.41 | Activation=54.41 | XE=9.92
# Runtime=0.33s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 133 | Operation: delete
# Loss=-55.28 | Activation=55.28 | XE=9.23
# Runtime=0.08s
# Best candidate:
#  `vatvisvatce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 134 | Operation: delete
# Loss=-55.25 | Activation=55.25 | XE=9.31
# Runtime=0.07s
# Best candidate:
#  `vatvisvatce`
#
# @
# Âutola label
#
#
#
# Iteration 135 | Operation: delete
# Loss=-55.01 | Activation=55.01 | XE=9.13
# Runtime=0.09s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 136 | Operation: gcg_swap
# Loss=-55.23 | Activation=55.23 | XE=9.87
# Runtime=0.31s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 137 | Operation: gcg_swap
# Loss=-54.53 | Activation=54.53 | XE=9.74
# Runtime=0.35s
# Best candidate:
#  `vatvisvataguce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 138 | Operation: delete
# Loss=-55.28 | Activation=55.28 | XE=9.23
# Runtime=0.07s
# Best candidate:
#  `vatvisvatce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 139 | Operation: gcg_swap
# Loss=-51.92 | Activation=51.92 | XE=9.97
# Runtime=0.32s
# Best candidate:
#  `vatvisce`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 140 | Operation: delete
# Loss=-55.01 | Activation=55.01 | XE=9.13
# Runtime=0.07s
# Best candidate:
#  `vatvisce`
#
# @
# Âutola label
#
#
#
# Iteration 141 | Operation: sample_swap
# Loss=-55.11 | Activation=55.11 | XE=9.53
# Runtime=0.24s
# Best candidate:
#  `vatvisvet`
#
# @
# Âutola label
#
#
#
# Iteration 142 | Operation: sample_swap
# Loss=-55.21 | Activation=55.21 | XE=9.88
# Runtime=0.23s
# Best candidate:
#  `vatvisvic`
#
# @
# Âutola label
#
#
#
# Iteration 143 | Operation: sample_insert
# Loss=-55.38 | Activation=55.38 | XE=9.74
# Runtime=0.27s
# Best candidate:
#  `vatvisvic`
#
# @
# ÂutolaÂ label
#
#
#
# Iteration 144 | Operation: sample_swap
# Loss=-55.28 | Activation=55.28 | XE=9.73
# Runtime=0.25s
# Best candidate:
#  `vatvisvic`
#
# @
# ÂÂutola label
#
#
#
# Iteration 145 | Operation: delete
# Loss=-55.19 | Activation=55.19 | XE=9.88
# Runtime=0.07s
# Best candidate:
#  `vatvisvic`
#
# @
# ÂÂutola label
#
#
#
# Iteration 146 | Operation: sample_insert
# Loss=-55.36 | Activation=55.36 | XE=9.27
# Runtime=0.27s
# Best candidate:
#  `vatvisvicc`
#
# @
# ÂÂutola label
#
#
#
# Iteration 147 | Operation: sample_swap
# Loss=-55.37 | Activation=55.37 | XE=9.97
# Runtime=0.26s
# Best candidate:
#  `vatmisvicc`
#
# @
# ÂÂutola label
#
#
#
# Iteration 148 | Operation: delete
# Loss=-55.28 | Activation=55.28 | XE=9.46
# Runtime=0.07s
# Best candidate:
#  `vatvisvicc`
#
# @
# ÂÂutola label
#
#
#
# Iteration 149 | Operation: sample_swap
# Loss=-55.33 | Activation=55.33 | XE=9.98
# Runtime=0.26s
# Best candidate:
#  `vatvisvicc`
#
# @
# ÂÂutola label

# %%
# %config InlineBackend.figure_format = 'retina'
plt.figure(figsize=(9, 4))
activations = [h["activation"] for h in encoder_history]
plt.plot(activations)
plt.annotate(
    repr(encoder_history[20]["seq"]),
    xy=(20, activations[20]),
    xytext=(40, activations[20] - 30),
    arrowprops=dict(facecolor="black", shrink=0.05),
    horizontalalignment="center",
    verticalalignment="bottom",
)
plt.annotate(
    repr(encoder_history[110]["seq"]),
    xy=(110, activations[110]),
    xytext=(110, activations[110] - 40),
    arrowprops=dict(facecolor="black", shrink=0.05),
    horizontalalignment="center",
    verticalalignment="bottom",
)
plt.xlabel("Iteration")
plt.ylabel("Activation")
plt.title("Activation History with Annotations")
plt.show()

# %% [markdown]
# ## Dreaming decoder directions
#
# Out of curiosity, do we get similar results if we apply feature visualization to the corresponding decoder direction?

# %%
def gemma_sae_decoder(gemma2, layer, feature_idx):
    def f(input_ids=None, inputs_embeds=None, attention_mask=None):
        out = {}

        def get_res(module, input, output):
            out["res"] = input[0]

        model_hooks = [
            (gemma2.model.layers[layer], get_res),
        ]
        with add_fwd_hooks(model_hooks):
            if inputs_embeds is not None:
                logits = gemma2(
                    inputs_embeds=inputs_embeds, attention_mask=attention_mask
                ).logits
            else:
                logits = gemma2(
                    input_ids=input_ids, attention_mask=attention_mask
                ).logits

        def get_sae_pre(module, input, output):
            out["sae_pre"] = input[0]

        sae = load_sae(layer)
        activation = out["res"][:, -1].to(sae.dtype) @ sae.W_dec[feature_idx]

        return activation, logits

    return f

# %% [markdown]
# Based on the correlation of 0.99, the answer appears to be an emphatic yes for this particular feature. However, it might be different for other features.

# %%
layer = 12
feature_idx = 0
texts = [
    "label",
    "labl",
    "LBL",
    "lbl",
    "LABEL",
    "labal",
    "L",
    "B",
    "bel",
    "la",
    "abel",
]

encoder_activations = []
decoder_activations = []

for text in texts:
    inputs = tokenizer([text], padding=True, return_tensors="pt")
    input_ids = inputs["input_ids"]
    encoder_activation, _ = gemma_sae_encoder(gemma2, layer, feature_idx)(
        input_ids=input_ids
    )
    decoder_activation, _ = gemma_sae_decoder(gemma2, layer, feature_idx)(
        input_ids=input_ids
    )
    encoder_activations.append(encoder_activation.item())
    decoder_activations.append(decoder_activation.item())

plt.figure(figsize=(10, 6))
plt.scatter(encoder_activations, decoder_activations)
plt.xlabel("Encoder Activations")
plt.ylabel("Decoder Activations")
plt.title("Correlation between Encoder and Decoder Activations")

# Add text labels for each point
for i, text in enumerate(texts):
    plt.annotate(
        text,
        (encoder_activations[i], decoder_activations[i]),
        xytext=(5, 5),
        textcoords="offset points",
    )

# Calculate and display correlation coefficient
correlation = np.corrcoef(encoder_activations, decoder_activations)[0, 1]
plt.text(
    0.05,
    0.95,
    f"Correlation: {correlation:.2f}",
    transform=plt.gca().transAxes,
    verticalalignment="top",
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Feature visualization on the decoder direction also acquires the "label" phrase:

# %%
# | output: false

decoder_history = dream(
    gemma2,
    tokenizer,
    get_feature_and_logits=gemma_sae_decoder(gemma2, layer, feature_idx),
    iters=150,
    init_prompt="help",
    xe_max=10.0,
)
# Out:
# Iteration 0 | Operation: sample_insert
# Loss=1.98 | Activation=-1.98 | XE=8.67
# Runtime=0.19s
# Best candidate: helpyou
#
#
#
# Iteration 1 | Operation: sample_insert
# Loss=-10.53 | Activation=10.53 | XE=9.80
# Runtime=0.19s
# Best candidate: helpyoubl
#
#
#
# Iteration 2 | Operation: sample_insert
# Loss=-7.22 | Activation=7.22 | XE=9.44
# Runtime=0.18s
# Best candidate: helpyoutable
#
#
#
# Iteration 3 | Operation: sample_insert
# Loss=-8.87 | Activation=8.87 | XE=9.78
# Runtime=0.19s
# Best candidate: helpyoutable
#
#
#
# Iteration 4 | Operation: sample_insert
# Loss=inf | Activation=7.61 | XE=13.97
# Runtime=0.18s
# Best candidate: helpyoupla
#
#
#
# Iteration 5 | Operation: sample_insert
# Loss=-14.15 | Activation=14.15 | XE=9.71
# Runtime=0.18s
# Best candidate: helpyouplab
#
#
#
# Iteration 6 | Operation: sample_insert
# Loss=-16.82 | Activation=16.82 | XE=7.47
# Runtime=0.18s
# Best candidate: helpyouplabbel
#
#
#
# Iteration 7 | Operation: sample_insert
# Loss=-33.79 | Activation=33.79 | XE=9.14
# Runtime=0.19s
# Best candidate: helpyouplabLbel
#
#
#
# Iteration 8 | Operation: sample_insert
# Loss=-40.25 | Activation=40.25 | XE=8.91
# Runtime=0.20s
# Best candidate: helpyouplabLbelabel
#
#
#
# Iteration 9 | Operation: gcg_swap
# Loss=-42.68 | Activation=42.68 | XE=8.70
# Runtime=0.25s
# Best candidate: helusiaiouplabLbelabel
#
#
#
# Iteration 10 | Operation: gcg_swap
# Loss=-44.83 | Activation=44.83 | XE=9.91
# Runtime=0.27s
# Best candidate: helusiaiouplatalletLbelabel
#
#
#
# Iteration 11 | Operation: sample_swap
# Loss=-45.57 | Activation=45.57 | XE=8.44
# Runtime=0.23s
# Best candidate: helusiaiouplatallet Metabolismbelabel
#
#
#
# Iteration 12 | Operation: sample_insert
# Loss=-46.37 | Activation=46.37 | XE=9.58
# Runtime=0.27s
# Best candidate: helusiaiouplatallet Metabolisolismbelabel
#
#
#
# Iteration 13 | Operation: sample_swap
# Loss=-46.91 | Activation=46.91 | XE=9.02
# Runtime=0.24s
# Best candidate: helusiaiouplatallet Computolisolismbelabel
#
#
#
# Iteration 14 | Operation: delete
# Loss=-48.32 | Activation=48.32 | XE=9.39
# Runtime=0.07s
# Best candidate: helusiaiouplatallet Computolisoliselabel
#
#
#
# Iteration 15 | Operation: sample_insert
# Loss=-51.23 | Activation=51.23 | XE=9.83
# Runtime=0.28s
# Best candidate: helusiaiouplatalablet Computolisoliselabel
#
#
#
# Iteration 16 | Operation: sample_swap
# Loss=-60.34 | Activation=60.34 | XE=9.79
# Runtime=0.25s
# Best candidate: helusiaiouplatalablet Computolisoli
#
# label
#
#
#
# Iteration 17 | Operation: sample_insert
# Loss=-60.92 | Activation=60.92 | XE=9.69
# Runtime=0.28s
# Best candidate: helusiaiouplatalablet Computolisploli
#
# label
#
#
#
# Iteration 18 | Operation: gcg_swap
# Loss=-62.31 | Activation=62.31 | XE=9.25
# Runtime=0.32s
# Best candidate: helusiaiouplatalablesetupUi Computolisploli
#
# label
#
#
#
# Iteration 19 | Operation: delete
# Loss=-62.37 | Activation=62.37 | XE=10.00
# Runtime=0.08s
# Best candidate: helusiouplatalablesetupUi Computolisploli
#
# label
#
#
#
# Iteration 20 | Operation: delete
# Loss=-62.00 | Activation=62.00 | XE=9.63
# Runtime=0.07s
# Best candidate: helusiouplatalablesetupUiutolisploli
#
# label
#
#
#
# Iteration 21 | Operation: delete
# Loss=-62.60 | Activation=62.60 | XE=9.80
# Runtime=0.07s
# Best candidate: helusiplatalablesetupUiutolisploli
#
# label
#
#
#
# Iteration 22 | Operation: sample_swap
# Loss=-63.17 | Activation=63.17 | XE=9.97
# Runtime=0.26s
# Best candidate: helusiplatalablesetupUiutolisplo0
#
# label
#
#
#
# Iteration 23 | Operation: sample_swap
# Loss=-63.11 | Activation=63.11 | XE=9.97
# Runtime=0.26s
# Best candidate: helusiplatalablesetupUiutolisplo0
#
# label
#
#
#
# Iteration 24 | Operation: sample_insert
# Loss=-63.29 | Activation=63.29 | XE=9.34
# Runtime=0.30s
# Best candidate: helusiplatalablesetupUiutolisplounas0
#
# label
#
#
#
# Iteration 25 | Operation: delete
# Loss=-63.69 | Activation=63.69 | XE=8.89
# Runtime=0.07s
# Best candidate: heluplatalablesetupUiutolisplounas0
#
# label
#
#
#
# Iteration 26 | Operation: sample_swap
# Loss=-64.23 | Activation=64.23 | XE=9.91
# Runtime=0.27s
# Best candidate: heluplatalablesetupUiutolisplcas0
#
# label
#
#
#
# Iteration 27 | Operation: delete
# Loss=-64.31 | Activation=64.31 | XE=9.77
# Runtime=0.07s
# Best candidate: heluatalablesetupUiutolisplcas0
#
# label
#
#
#
# Iteration 28 | Operation: sample_swap
# Loss=-64.00 | Activation=64.00 | XE=9.71
# Runtime=0.24s
# Best candidate: heluplatalablesetupUiutoplcas0
#
# label
#
#
#
# Iteration 29 | Operation: gcg_swap
# Loss=-63.83 | Activation=63.83 | XE=9.96
# Runtime=0.30s
# Best candidate: heplatalablesetupUiutolisplcas0
#
# label
#
#
#
# Iteration 30 | Operation: delete
# Loss=-64.24 | Activation=64.24 | XE=9.82
# Runtime=0.07s
# Best candidate: heplablesetupUiutolisplcas0
#
# label
#
#
#
# Iteration 31 | Operation: gcg_swap
# Loss=-62.47 | Activation=62.47 | XE=9.83
# Runtime=0.29s
# Best candidate: heluplatalablesetuputolisplcas0
#
# label
#
#
#
# Iteration 32 | Operation: gcg_swap
# Loss=-63.99 | Activation=63.99 | XE=9.72
# Runtime=0.31s
# Best candidate: heluatalablesetupMputolisplcas0
#
# label
#
#
#
# Iteration 33 | Operation: gcg_swap
# Loss=inf | Activation=61.42 | XE=11.44
# Runtime=0.31s
# Best candidate: heluplatalablesetup andlisplcas0
#
# label
#
#
#
# Iteration 34 | Operation: sample_swap
# Loss=-64.62 | Activation=64.62 | XE=9.64
# Runtime=0.24s
# Best candidate: heluplatalablesetup ulisplcas0
#
# label
#
#
#
# Iteration 35 | Operation: sample_swap
# Loss=-65.00 | Activation=65.00 | XE=9.96
# Runtime=0.24s
# Best candidate: heluplatalablesetup ul isplcas0
#
# label
#
#
#
# Iteration 36 | Operation: delete
# Loss=-65.27 | Activation=65.27 | XE=9.38
# Runtime=0.07s
# Best candidate: luplatalablesetup ul isplcas0
#
# label
#
#
#
# Iteration 37 | Operation: delete
# Loss=-65.11 | Activation=65.11 | XE=9.61
# Runtime=0.07s
# Best candidate: heplatalablesetup ul isplcas0
#
# label
#
#
#
# Iteration 38 | Operation: delete
# Loss=-65.02 | Activation=65.02 | XE=9.80
# Runtime=0.07s
# Best candidate: luplatalableset ul isplcas0
#
# label
#
#
#
# Iteration 39 | Operation: sample_swap
# Loss=-64.25 | Activation=64.25 | XE=9.94
# Runtime=0.22s
# Best candidate: heluplatalablesetup isplcas0
#
# label
#
#
#
# Iteration 40 | Operation: sample_swap
# Loss=-65.14 | Activation=65.14 | XE=8.65
# Runtime=0.22s
# Best candidate: heluplatalablesetup isplcas0
#
# label
#
#
#
# Iteration 41 | Operation: delete
# Loss=-65.10 | Activation=65.10 | XE=9.35
# Runtime=0.07s
# Best candidate: heluplatalablesetup isplcas0
#
# label
#
#
#
# Iteration 42 | Operation: sample_insert
# Loss=-65.27 | Activation=65.27 | XE=9.78
# Runtime=0.27s
# Best candidate: heluplatalablesetbup isplcas0
#
# label
#
#
#
# Iteration 43 | Operation: delete
# Loss=-65.48 | Activation=65.48 | XE=8.82
# Runtime=0.07s
# Best candidate: heluplatalablesetp isplcas0
#
# label
#
#
#
# Iteration 44 | Operation: delete
# Loss=-65.41 | Activation=65.41 | XE=9.81
# Runtime=0.07s
# Best candidate: heluatalablesetp isplcas0
#
# label
#
#
#
# Iteration 45 | Operation: sample_insert
# Loss=-65.88 | Activation=65.88 | XE=9.31
# Runtime=0.25s
# Best candidate: heluatalablesetp isplcasc0
#
# label
#
#
#
# Iteration 46 | Operation: gcg_swap
# Loss=-65.26 | Activation=65.26 | XE=9.92
# Runtime=0.29s
# Best candidate: heluatalablesetp isplcaspl0
#
# label
#
#
#
# Iteration 47 | Operation: sample_swap
# Loss=-64.90 | Activation=64.90 | XE=9.96
# Runtime=0.23s
# Best candidate: heluatalablesetp isplcaspc0
#
# label
#
#
#
# Iteration 48 | Operation: delete
# Loss=-65.96 | Activation=65.96 | XE=9.96
# Runtime=0.07s
# Best candidate: heluatalablesetp isplcaspc
#
# label
#
#
#
# Iteration 49 | Operation: sample_insert
# Loss=-64.18 | Activation=64.18 | XE=9.78
# Runtime=0.26s
# Best candidate: heluatalablesetp isplcasat0
#
# label
#
#
#
# Iteration 50 | Operation: sample_swap
# Loss=-65.72 | Activation=65.72 | XE=9.18
# Runtime=0.23s
# Best candidate: heluatalablesetp isplcasp0
#
# label
#
#
#
# Iteration 51 | Operation: delete
# Loss=-65.58 | Activation=65.58 | XE=9.73
# Runtime=0.07s
# Best candidate: luatalablesetp isplcasp0
#
# label
#
#
#
# Iteration 52 | Operation: sample_swap
# Loss=-65.92 | Activation=65.92 | XE=9.74
# Runtime=0.23s
# Best candidate: lualablesetp isplcasp0
#
# label
#
#
#
# Iteration 53 | Operation: gcg_swap
# Loss=-64.62 | Activation=64.62 | XE=9.93
# Runtime=0.28s
# Best candidate: heluatalablesetp isplcasatms
#
# label
#
#
#
# Iteration 54 | Operation: sample_swap
# Loss=-63.04 | Activation=63.04 | XE=9.65
# Runtime=0.24s
# Best candidate: heluatalablesetp isplcascas0
#
# label
#
#
#
# Iteration 55 | Operation: sample_insert
# Loss=-65.58 | Activation=65.58 | XE=9.99
# Runtime=0.27s
# Best candidate: heluatalablesetp isplcascaspl0
#
# label
#
#
#
# Iteration 56 | Operation: sample_swap
# Loss=-66.21 | Activation=66.21 | XE=9.91
# Runtime=0.24s
# Best candidate: heluatalablesetp isplcascasplts
#
# label
#
#
#
# Iteration 57 | Operation: sample_insert
# Loss=-66.12 | Activation=66.12 | XE=9.93
# Runtime=0.30s
# Best candidate: heluatalablesetp isplcasnetcasplts
#
# label
#
#
#
# Iteration 58 | Operation: delete
# Loss=-66.26 | Activation=66.26 | XE=9.75
# Runtime=0.07s
# Best candidate: luatalablesetp isplcasnetcasplts
#
# label
#
#
#
# Iteration 59 | Operation: sample_insert
# Loss=-66.64 | Activation=66.64 | XE=9.36
# Runtime=0.27s
# Best candidate: luatalablesetp isplcascnetcasplts
#
# label
#
#
#
# Iteration 60 | Operation: sample_swap
# Loss=-66.63 | Activation=66.63 | XE=9.90
# Runtime=0.25s
# Best candidate: luatalablesetp isplcascnetlplts
#
# label
#
#
#
# Iteration 61 | Operation: gcg_swap
# Loss=-65.57 | Activation=65.57 | XE=9.93
# Runtime=0.33s
# Best candidate: luatalablesetp isplcascnetcasplcl
#
# label
#
#
#
# Iteration 62 | Operation: gcg_swap
# Loss=-65.28 | Activation=65.28 | XE=9.74
# Runtime=0.33s
# Best candidate: luatalablesetp isplcasnetcaspltscr
#
# label
#
#
#
# Iteration 63 | Operation: delete
# Loss=-66.30 | Activation=66.30 | XE=9.43
# Runtime=0.07s
# Best candidate: lu luatalablesetp isplcasnetcasplts
#
# label
#
#
#
# Iteration 64 | Operation: sample_insert
# Loss=-66.60 | Activation=66.60 | XE=9.47
# Runtime=0.29s
# Best candidate: lu luatalablesetp isplcasnetcaspltspl
#
# label
#
#
#
# Iteration 65 | Operation: delete
# Loss=-66.58 | Activation=66.58 | XE=9.58
# Runtime=0.07s
# Best candidate: lu luatalablesetp isplnetcaspltspl
#
# label
#
#
#
# Iteration 66 | Operation: sample_swap
# Loss=-66.19 | Activation=66.19 | XE=9.98
# Runtime=0.26s
# Best candidate: lu lu loatalablesetp isplcasnetcasplts
#
# label
#
#
#
# Iteration 67 | Operation: delete
# Loss=-66.60 | Activation=66.60 | XE=9.66
# Runtime=0.07s
# Best candidate: lu lu loatalableset isplcasnetcasplts
#
# label
#
#
#
# Iteration 68 | Operation: gcg_swap
# Loss=inf | Activation=65.71 | XE=11.79
# Runtime=0.30s
# Best candidate: lu lu loatalablesetp isplnetcasplts
#
# label
#
#
#
# Iteration 69 | Operation: sample_swap
# Loss=-66.69 | Activation=66.69 | XE=9.12
# Runtime=0.24s
# Best candidate: lu lu loatalablesetp isplnetestplts
#
# label
#
#
#
# Iteration 70 | Operation: gcg_swap
# Loss=-63.37 | Activation=63.37 | XE=8.94
# Runtime=0.32s
# Best candidate: lu lu loatalablesetp isplcascasplts
#
# label
#
#
#
# Iteration 71 | Operation: gcg_swap
# Loss=-63.04 | Activation=63.04 | XE=9.46
# Runtime=0.33s
# Best candidate: lu lu loatalablesetmp isplnetcasplts
#
# label
#
#
#
# Iteration 72 | Operation: gcg_swap
# Loss=-46.83 | Activation=46.83 | XE=9.66
# Runtime=0.33s
# Best candidate: lu luatalablesetp isplcascaspltspl
#
# label
#
#
#
# Iteration 73 | Operation: sample_insert
# Loss=-66.69 | Activation=66.69 | XE=9.29
# Runtime=0.28s
# Best candidate: lu luatalablesetp isplcascaspltsplms
#
# label
#
#
#
# Iteration 74 | Operation: gcg_swap
# Loss=-64.65 | Activation=64.65 | XE=9.83
# Runtime=0.33s
# Best candidate: lu luatalablesetp isplcascasdpltspl
#
# label
#
#
#
# Iteration 75 | Operation: delete
# Loss=-66.67 | Activation=66.67 | XE=9.56
# Runtime=0.08s
# Best candidate: lu luatalablesetp isplcasdpltspl
#
# label
#
#
#
# Iteration 76 | Operation: sample_insert
# Loss=-66.96 | Activation=66.96 | XE=9.18
# Runtime=0.28s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 77 | Operation: delete
# Loss=-66.67 | Activation=66.67 | XE=9.56
# Runtime=0.08s
# Best candidate: lu luatalablesetp isplcasdpltsbelpl
#
# label
#
#
#
# Iteration 78 | Operation: delete
# Loss=-66.67 | Activation=66.67 | XE=9.56
# Runtime=0.07s
# Best candidate: lu luatalablesetp isplcasdpltspl
#
# label
#
#
#
# Iteration 79 | Operation: sample_swap
# Loss=-66.67 | Activation=66.67 | XE=9.55
# Runtime=0.24s
# Best candidate: lu luatalablesetp isplcasdpltspl
#
# label
#
#
#
# Iteration 80 | Operation: sample_insert
# Loss=-66.96 | Activation=66.96 | XE=9.18
# Runtime=0.28s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 81 | Operation: sample_insert
# Loss=-66.83 | Activation=66.83 | XE=9.88
# Runtime=0.30s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 82 | Operation: sample_swap
# Loss=-66.96 | Activation=66.96 | XE=9.18
# Runtime=0.25s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 83 | Operation: sample_insert
# Loss=-66.83 | Activation=66.83 | XE=9.88
# Runtime=0.30s
# Best candidate: lu luatalablesetp isplcasdpltsplpl
#
# label
#
#
#
# Iteration 84 | Operation: gcg_swap
# Loss=-64.36 | Activation=64.36 | XE=9.64
# Runtime=0.31s
# Best candidate: lu luatalablesetp isplcasdpltsplpl
#
# label
#
#
#
# Iteration 85 | Operation: sample_swap
# Loss=-66.55 | Activation=66.55 | XE=9.91
# Runtime=0.26s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 86 | Operation: sample_swap
# Loss=-66.96 | Activation=66.96 | XE=9.18
# Runtime=0.26s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 87 | Operation: sample_insert
# Loss=-66.81 | Activation=66.81 | XE=9.42
# Runtime=0.29s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 88 | Operation: sample_insert
# Loss=-66.90 | Activation=66.90 | XE=8.94
# Runtime=0.29s
# Best candidate: lu luatalablesetp isplcasdcaspltsplpl
#
# label
#
#
#
# Iteration 89 | Operation: delete
# Loss=-66.80 | Activation=66.80 | XE=9.32
# Runtime=0.07s
# Best candidate: lu luatalablesetpeld isplcasdcaspltspl
#
# label
#
#
#
# Iteration 90 | Operation: delete
# Loss=-66.81 | Activation=66.81 | XE=9.54
# Runtime=0.08s
# Best candidate: lu luatalablesetp isplcasdcaspltspl
#
# label
#
#
#
# Iteration 91 | Operation: sample_swap
# Loss=-66.73 | Activation=66.73 | XE=9.85
# Runtime=0.26s
# Best candidate: lu luatalablesetp is wplcasdcaspltspl
#
# label
#
#
#
# Iteration 92 | Operation: delete
# Loss=-66.94 | Activation=66.94 | XE=9.68
# Runtime=0.08s
# Best candidate: lu luatalablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 93 | Operation: sample_swap
# Loss=-67.21 | Activation=67.21 | XE=9.77
# Runtime=0.25s
# Best candidate: lu loatalablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 94 | Operation: sample_insert
# Loss=-66.86 | Activation=66.86 | XE=9.89
# Runtime=0.30s
# Best candidate: lu luatalablesetp is wcasdcasplcaspl
#
# label
#
#
#
# Iteration 95 | Operation: gcg_swap
# Loss=-65.07 | Activation=65.07 | XE=9.75
# Runtime=0.33s
# Best candidate: lu luatalablesetp is wplcasdcasplts
#
# label
#
#
#
# Iteration 96 | Operation: gcg_swap
# Loss=-63.99 | Activation=63.99 | XE=9.74
# Runtime=0.33s
# Best candidate: lu luatalablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 97 | Operation: sample_insert
# Loss=-67.07 | Activation=67.07 | XE=9.71
# Runtime=0.29s
# Best candidate: lu luatalualablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 98 | Operation: delete
# Loss=-67.10 | Activation=67.10 | XE=9.61
# Runtime=0.07s
# Best candidate: lu luualablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 99 | Operation: gcg_swap
# Loss=-65.22 | Activation=65.22 | XE=9.90
# Runtime=0.31s
# Best candidate: lu luatalualablesetp is wcasdcasplts
#
# label
#
#
#
# Iteration 100 | Operation: gcg_swap
# Loss=inf | Activation=64.86 | XE=11.25
# Runtime=0.33s
# Best candidate: lu lu loatalablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 101 | Operation: delete
# Loss=-67.11 | Activation=67.11 | XE=9.77
# Runtime=0.08s
# Best candidate: lu loatalablesetp is wcasdcaspltspl
#
# label
#
#
#
# Iteration 102 | Operation: sample_insert
# Loss=-67.35 | Activation=67.35 | XE=9.63
# Runtime=0.29s
# Best candidate: lu loatalablesetp is wcasdcaspltsplpl
#
# label
#
#
#
# Iteration 103 | Operation: delete
# Loss=-67.26 | Activation=67.26 | XE=9.79
# Runtime=0.07s
# Best candidate: lu loatalablesetp is wcasdcaspltsplpl
#
# label
#
#
#
# Iteration 104 | Operation: delete
# Loss=-67.26 | Activation=67.26 | XE=9.79
# Runtime=0.07s
# Best candidate: lu loatalablesetp is wcasdcaspltsplpl
#
# label
#
#
#
# Iteration 105 | Operation: delete
# Loss=-67.26 | Activation=67.26 | XE=9.79
# Runtime=0.07s
# Best candidate: lu loatalablesetp is wcasdcaspltsplcas
#
# label
#
#
#
# Iteration 106 | Operation: delete
# Loss=-67.43 | Activation=67.43 | XE=9.89
# Runtime=0.07s
# Best candidate: lu loatalablesetp is wcasdcasplplcas
#
# label
#
#
#
# Iteration 107 | Operation: delete
# Loss=-67.03 | Activation=67.03 | XE=9.90
# Runtime=0.07s
# Best candidate: lu loatalableset is wcasdcaspltsplcas
#
# label
#
#
#
# Iteration 108 | Operation: sample_insert
# Loss=-66.77 | Activation=66.77 | XE=9.89
# Runtime=0.30s
# Best candidate: lu loatalablesetp is wcasdcasplplpl
#
# label
#
#
#
# Iteration 109 | Operation: delete
# Loss=-66.88 | Activation=66.88 | XE=9.73
# Runtime=0.07s
# Best candidate: lu loatalablesetp is wcasdcasplplpl
#
# label
#
#
#
# Iteration 110 | Operation: gcg_swap
# Loss=-66.74 | Activation=66.74 | XE=9.93
# Runtime=0.33s
# Best candidate: lu loatalablesetp wcasdcasplplcas
#
# label
#
#
#
# Iteration 111 | Operation: sample_insert
# Loss=-66.65 | Activation=66.65 | XE=8.93
# Runtime=0.29s
# Best candidate: lu loatalablesetp wcasdcasplplpl
#
# label
#
#
#
# Iteration 112 | Operation: sample_swap
# Loss=-66.24 | Activation=66.24 | XE=9.93
# Runtime=0.27s
# Best candidate: luatalablesetp is wcasdcasplplpl
#
# label
#
#
#
# Iteration 113 | Operation: gcg_swap
# Loss=-65.39 | Activation=65.39 | XE=9.79
# Runtime=0.31s
# Best candidate: lu loablesetp is wcasdcasplplpl
#
# label
#
#
#
# Iteration 114 | Operation: gcg_swap
# Loss=-65.68 | Activation=65.68 | XE=9.40
# Runtime=0.30s
# Best candidate: lu loatalablesetp wcasdcasplplddcas
#
# label
#
#
#
# Iteration 115 | Operation: delete
# Loss=-66.92 | Activation=66.92 | XE=9.07
# Runtime=0.07s
# Best candidate: lu loatalableset wcasdcasplplddcas
#
# label
#
#
#
# Iteration 116 | Operation: sample_insert
# Loss=-67.02 | Activation=67.02 | XE=8.65
# Runtime=0.29s
# Best candidate: lu loatalableset wcasdcasplplddcasl
#
# label
#
#
#
# Iteration 117 | Operation: delete
# Loss=-67.05 | Activation=67.05 | XE=9.03
# Runtime=0.07s
# Best candidate: lu loatalableset wcasdcasplpldcasl
#
# label
#
#
#
# Iteration 118 | Operation: sample_insert
# Loss=-67.13 | Activation=67.13 | XE=9.35
# Runtime=0.30s
# Best candidate: lu loatalableset wcasdcasplpldcaslpl
#
# label
#
#
#
# Iteration 119 | Operation: delete
# Loss=-67.05 | Activation=67.05 | XE=9.03
# Runtime=0.07s
# Best candidate: lu loatalableset wcasdcasplfinpldcasl
#
# label
#
#
#
# Iteration 120 | Operation: delete
# Loss=-67.05 | Activation=67.05 | XE=9.03
# Runtime=0.09s
# Best candidate: lu loatalableset wcasdcascasplpldcasl
#
# label
#
#
#
# Iteration 121 | Operation: delete
# Loss=-67.05 | Activation=67.05 | XE=9.03
# Runtime=0.09s
# Best candidate: lu loatalableset wcasdcasplpldcasl
#
# label
#
#
#
# Iteration 122 | Operation: sample_swap
# Loss=-67.58 | Activation=67.58 | XE=9.77
# Runtime=0.27s
# Best candidate: lu meluatalableset wcasdcasplpldcasl
#
# label
#
#
#
# Iteration 123 | Operation: delete
# Loss=-67.40 | Activation=67.40 | XE=9.65
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpldcasl
#
# label
#
#
#
# Iteration 124 | Operation: delete
# Loss=-67.29 | Activation=67.29 | XE=9.75
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpcasl
#
# label
#
#
#
# Iteration 125 | Operation: sample_insert
# Loss=-67.44 | Activation=67.44 | XE=9.65
# Runtime=0.27s
# Best candidate: lu meluatalableset wcasdplpldcasl
#
# label
#
#
#
# Iteration 126 | Operation: delete
# Loss=-67.29 | Activation=67.29 | XE=9.75
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpldcasl
#
# label
#
#
#
# Iteration 127 | Operation: sample_insert
# Loss=-67.47 | Activation=67.47 | XE=9.72
# Runtime=0.28s
# Best candidate: lu meluatalableset
#
#  wcasdplpldcasl
#
# label
#
#
#
# Iteration 128 | Operation: sample_insert
# Loss=-67.75 | Activation=67.75 | XE=9.43
# Runtime=0.29s
# Best candidate: lu meluatalableset
#
#  wcasd wplpldcasl
#
# label
#
#
#
# Iteration 129 | Operation: delete
# Loss=-67.61 | Activation=67.61 | XE=9.62
# Runtime=0.08s
# Best candidate: lu meluatalableset
#
#  wcasd wplpcasl
#
# label
#
#
#
# Iteration 130 | Operation: delete
# Loss=-67.55 | Activation=67.55 | XE=9.97
# Runtime=0.07s
# Best candidate: lu meluatalableset
#
#  wcasd wplcasl
#
# label
#
#
#
# Iteration 131 | Operation: delete
# Loss=-67.17 | Activation=67.17 | XE=9.75
# Runtime=0.07s
# Best candidate: lu meluatalableset
#
#  wcasdplpldcasl
#
# label
#
#
#
# Iteration 132 | Operation: delete
# Loss=-67.40 | Activation=67.40 | XE=9.65
# Runtime=0.07s
# Best candidate: lu meluatalableset
#
#  wcasd wplpldl
#
# label
#
#
#
# Iteration 133 | Operation: sample_swap
# Loss=-66.72 | Activation=66.72 | XE=9.81
# Runtime=0.26s
# Best candidate: lu meluatalableset
#
#  wcasdplpldplcasl
#
# label
#
#
#
# Iteration 134 | Operation: delete
# Loss=-67.54 | Activation=67.54 | XE=9.72
# Runtime=0.08s
# Best candidate: lu meluatalableset
#
#  wcasdplpldcasl
#
# label
#
#
#
# Iteration 135 | Operation: delete
# Loss=-67.40 | Activation=67.40 | XE=9.65
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpldplcasl
#
# label
#
#
#
# Iteration 136 | Operation: sample_insert
# Loss=-67.57 | Activation=67.57 | XE=9.78
# Runtime=0.31s
# Best candidate: lu meluatalableset wcasd wplpldplcasl
#
# label
#
#
#
# Iteration 137 | Operation: delete
# Loss=-67.48 | Activation=67.48 | XE=9.32
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdcasplpldplcasl
#
# label
#
#
#
# Iteration 138 | Operation: delete
# Loss=-67.48 | Activation=67.48 | XE=9.32
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpldplcasl
#
# label
#
#
#
# Iteration 139 | Operation: sample_insert
# Loss=-67.44 | Activation=67.44 | XE=10.00
# Runtime=0.30s
# Best candidate: lu meluatalableset wcasdplpldplcasl
#
# label
#
#
#
# Iteration 140 | Operation: sample_swap
# Loss=-67.35 | Activation=67.35 | XE=9.82
# Runtime=0.26s
# Best candidate: lu meluatalableset wcas wplpldplcasl
#
# label
#
#
#
# Iteration 141 | Operation: sample_insert
# Loss=-67.37 | Activation=67.37 | XE=9.58
# Runtime=0.29s
# Best candidate: lu meluatalableset wcasdplpldlplcasl
#
# label
#
#
#
# Iteration 142 | Operation: delete
# Loss=-67.48 | Activation=67.48 | XE=9.32
# Runtime=0.08s
# Best candidate: lu meluatalableset wcasdplpldplcasl
#
# label
#
#
#
# Iteration 143 | Operation: delete
# Loss=-67.40 | Activation=67.40 | XE=9.65
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasdplpldplcasl
#
# label
#
#
#
# Iteration 144 | Operation: sample_swap
# Loss=-67.41 | Activation=67.41 | XE=9.64
# Runtime=0.26s
# Best candidate: lu meluatalableset wcasdplcasldplcasl
#
# label
#
#
#
# Iteration 145 | Operation: gcg_swap
# Loss=-66.71 | Activation=66.71 | XE=9.77
# Runtime=0.33s
# Best candidate: lu meluatalableset wcasdplcasldplcasl
#
# label
#
#
#
# Iteration 146 | Operation: sample_insert
# Loss=-67.54 | Activation=67.54 | XE=9.50
# Runtime=0.30s
# Best candidate: lu meluatalableset wcasd wplcasldplcasl
#
# label
#
#
#
# Iteration 147 | Operation: delete
# Loss=-67.50 | Activation=67.50 | XE=8.93
# Runtime=0.09s
# Best candidate: lu meluatalableset wcasdplcasldplcasl
#
# label
#
#
#
# Iteration 148 | Operation: gcg_swap
# Loss=-66.82 | Activation=66.82 | XE=9.28
# Runtime=0.33s
# Best candidate: lu meluatalableset wcasd wplcasldcasl
#
# label
#
#
#
# Iteration 149 | Operation: delete
# Loss=-67.31 | Activation=67.31 | XE=9.69
# Runtime=0.07s
# Best candidate: lu meluatalableset wcasd wplcasplcasl
#
# label
